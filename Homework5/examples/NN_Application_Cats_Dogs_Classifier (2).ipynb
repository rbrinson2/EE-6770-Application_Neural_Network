# %% [markdown]
# # <center>Neural Network Application: Image Classification </center>

# %% [markdown]
# ## The Cats & Dogs Dataset
# <img src="cat_dog_dataset.jpg" alt="Drawing" style="width: 600px;"/>
#
# * ### You can download the photos folders from Kaggle: https://www.kaggle.com/c/dogs-vs-cats
# * ### Download train.zip and unzip the 25000 files and move them to a folder and make a note of the file path

# %% [markdown]
# ### Import Toolsets

# %%
import os, itertools 
import time
import random, shutil
import numpy as np 
import pandas as pd 
 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Import TensorFlow and Keras

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### Image Preprocessing tool

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# ## <font color= blue>Load and Process the Dataset</font>
#
# One of the more time consuming, yet critcally important step, is to prepare the dataset to be ready for the neural network training workflow. After retreiving the data files (images of dogs and cats, 25,000 each), we want to perform the following tasks:
# * `Randomly pick a subset of $N$ samples from the training dataset.` This step is only for learning purposes to save time. Once you are ready to train the entire dataset, you can skip this step. Nonetheless, this step illustrates some Python directory commands that can be useful.
# * `Create target labels` for the subset, Dog for class = 1, Cat for class = 0.
# * `Split the data into train set and test set.`

# %% [markdown]
# ### Create a directory and store $N$ randomly selected data

# %%
# Path to the main dataset directory. You specify your directory path for data.
train_path = '../train'

# Path to the directory where you want to save the subset
train_sub_path = './train_2000'

# Create the subset directory if it doesn't exist
os.makedirs(train_sub_path, exist_ok=True)

# Number of samples to select from the original training set 
num_samples = 2000

# Randomly select N samples (cats and dogs mixed)
files = os.listdir(train_path)
selected_files = random.sample(files, num_samples)

# Copy selected files to the subset directory
for file in selected_files:
    src_path = os.path.join(train_path, file)
    dst_path = os.path.join(train_sub_path, file)
    shutil.copy(src_path, dst_path)

# List the first 10 image files
os.listdir(train_sub_path)[0:10]
# Out:
# ['cat.10004.jpg',
#  'cat.10009.jpg',
#  'cat.10019.jpg',
#  'cat.1004.jpg',
#  'cat.10055.jpg',
#  'cat.10060.jpg',
#  'cat.10062.jpg',
#  'cat.10088.jpg',
#  'cat.10100.jpg',
#  'cat.1011.jpg']

# %% [markdown]
# ### Randomly pick an image from the newly created train set

# %%
directory = os.listdir(train_sub_path)
sample = random.choice(directory)
sample
# Out:
# 'cat.12118.jpg'

# %%
img = load_img(os.path.join(train_sub_path, sample))

plt.imshow(img)
plt.show()

# %% [markdown]
# ### The images come in differeny shapes and resolutions. For practical implementations, we usually reduce the image to smaller sizes, such as 64 by 64 pixel.

# %%
img = load_img(os.path.join(train_sub_path, sample), target_size=(64, 64))

# Converting the image to a 3-dimensional array 
img_array = img_to_array(img)

plt.imshow(img)
plt.show()

# %%
img_array.shape
# Out:
# (64, 64, 3)

# %% [markdown]
# ### NumPy approach to create (resized) input image arrays and target labels

# %%
# parameters for image size 
rows = 64  
cols = 64
channels = 3  # RGB

# %%
X = []  # training images
y = []  # class labels

for file in os.listdir(train_sub_path):
    # Load image and resize
    img = load_img(os.path.join(train_sub_path, file), target_size=(rows, cols))
    
    # Important: Convert image to array and normalize pixel values
    img_array = img_to_array(img) / 255.0
    
    # Append to the list
    X.append(img_array)
    
    # Extract label from filename (assuming file name is like 'cat.1.jpg' or 'dog.1.jpg')
    label = 1 if "dog" in file else 0
    
    y.append(label)

# %%
X = np.array(X)
X.shape
# Out:
# (2000, 64, 64, 3)

# %%
y = np.array(y)
print (y.shape)
print ("# of dogs =", y.sum())
# Out:
# (2000,)
# # of dogs = 984

# %% [markdown]
# ### Important step: flatten the image from 3-D to 1-D vector!

# %%
X = X.reshape(X.shape[0], -1)
X.shape
# Out:
# (2000, 12288)

# %% [markdown]
# ### $N$ input samples, each with 64$\times$64$\times$3 = 12,288 features!

# %% [markdown]
# ### Before training the NN model, split the dataset into train set and test set.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
X_train.shape, y_test.shape
# Out:
# ((1400, 12288), (600,))

# %% [markdown]
# ## <font color= blue>Building an $L$-Layer Neural Network with Keras </font>

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ### Neural Network Layer Hyperparameters

# %%
L = 2

n0 = X.shape[1]  # number of input features, that is, 12,288 in this example
n1 = 8  # number of neurons in the hidden layer
n2 = 1  # number of neurons in the output layer

# %%
n0
# Out:
# 12288

# %% [markdown]
# ### <font color=blue>1. Define the NN model </font>

# %%
model = Sequential()

model.add(Dense(n1, input_dim=n0, activation="relu"))

model.add(Dense(n2, activation="sigmoid"))

# %% [markdown]
# ### <font color=blue>2. Compile the Keras Model</font>

# %%
sgd = keras.optimizers.SGD(learning_rate=0.005)

model.compile(loss="binary_crossentropy", optimizer=sgd, metrics=["accuracy"])

# %% [markdown]
# ### <font color=blue>3. Train and Fit the Model</font>
#
# Note: when setting `verbose = 1`, the training progress will be displayed every epoch. Disable the feature when running large dataset.

# %%
history = model.fit(X_train, y_train, epochs=200, batch_size=20, validation_split=0.20, verbose=1)
# Out:
# Epoch 1/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.6965 - accuracy: 0.4911 - val_loss: 0.6919 - val_accuracy: 0.5250
# Epoch 2/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6916 - accuracy: 0.5393 - val_loss: 0.6874 - val_accuracy: 0.5143
# Epoch 3/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5464 - val_loss: 0.6785 - val_accuracy: 0.5571
# Epoch 4/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6766 - accuracy: 0.5562 - val_loss: 0.6728 - val_accuracy: 0.5750
# Epoch 5/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6698 - accuracy: 0.5804 - val_loss: 0.6774 - val_accuracy: 0.5536
# Epoch 6/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6650 - accuracy: 0.5741 - val_loss: 0.6825 - val_accuracy: 0.5607
# Epoch 7/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.5964 - val_loss: 0.6834 - val_accuracy: 0.5643
# Epoch 8/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6534 - accuracy: 0.5964 - val_loss: 0.6699 - val_accuracy: 0.6071
# Epoch 9/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6565 - accuracy: 0.6089 - val_loss: 0.6769 - val_accuracy: 0.5750
# Epoch 10/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6446 - accuracy: 0.6161 - val_loss: 0.7263 - val_accuracy: 0.5429
# Epoch 11/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6509 - accuracy: 0.6161 - val_loss: 0.6699 - val_accuracy: 0.6000
# Epoch 12/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6384 - accuracy: 0.6446 - val_loss: 0.6704 - val_accuracy: 0.5893
# Epoch 13/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6287 - accuracy: 0.6446 - val_loss: 0.6687 - val_accuracy: 0.6143
# Epoch 14/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.6228 - accuracy: 0.6464 - val_loss: 0.6961 - val_accuracy: 0.5714
# Epoch 15/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6292 - accuracy: 0.6402 - val_loss: 0.6671 - val_accuracy: 0.6071
# Epoch 16/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6209 - accuracy: 0.6509 - val_loss: 0.6714 - val_accuracy: 0.5964
# Epoch 17/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6099 - accuracy: 0.6705 - val_loss: 0.6734 - val_accuracy: 0.6036
# Epoch 18/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6130 - accuracy: 0.6482 - val_loss: 0.6760 - val_accuracy: 0.6036
# Epoch 19/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6077 - accuracy: 0.6554 - val_loss: 0.6717 - val_accuracy: 0.6000
# Epoch 20/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5993 - accuracy: 0.6768 - val_loss: 0.6618 - val_accuracy: 0.6036
# Epoch 21/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5902 - accuracy: 0.6884 - val_loss: 0.6636 - val_accuracy: 0.6000
# Epoch 22/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5931 - accuracy: 0.6670 - val_loss: 0.6732 - val_accuracy: 0.5929
# Epoch 23/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5848 - accuracy: 0.6938 - val_loss: 0.6765 - val_accuracy: 0.5750
# Epoch 24/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5760 - accuracy: 0.7018 - val_loss: 0.6747 - val_accuracy: 0.5929
# Epoch 25/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5744 - accuracy: 0.7018 - val_loss: 0.6936 - val_accuracy: 0.5607
# Epoch 26/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5773 - accuracy: 0.7018 - val_loss: 0.6724 - val_accuracy: 0.5857
# Epoch 27/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5656 - accuracy: 0.7107 - val_loss: 0.6727 - val_accuracy: 0.6000
# Epoch 28/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5665 - accuracy: 0.7045 - val_loss: 0.6901 - val_accuracy: 0.5964
# Epoch 29/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5688 - accuracy: 0.7018 - val_loss: 0.7162 - val_accuracy: 0.5786
# Epoch 30/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5421 - accuracy: 0.7277 - val_loss: 0.6864 - val_accuracy: 0.6036
# Epoch 31/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5372 - accuracy: 0.7348 - val_loss: 0.6838 - val_accuracy: 0.5786
# Epoch 32/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.7304 - val_loss: 0.6802 - val_accuracy: 0.6143
# Epoch 33/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5346 - accuracy: 0.7357 - val_loss: 0.7067 - val_accuracy: 0.5571
# Epoch 34/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5301 - accuracy: 0.7357 - val_loss: 0.6742 - val_accuracy: 0.5821
# Epoch 35/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5301 - accuracy: 0.7277 - val_loss: 0.6949 - val_accuracy: 0.5750
# Epoch 36/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5162 - accuracy: 0.7500 - val_loss: 0.7190 - val_accuracy: 0.5821
# Epoch 37/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5412 - accuracy: 0.7196 - val_loss: 0.7064 - val_accuracy: 0.5750
# Epoch 38/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.7339 - val_loss: 0.7749 - val_accuracy: 0.5179
# Epoch 39/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5097 - accuracy: 0.7339 - val_loss: 0.7156 - val_accuracy: 0.5643
# Epoch 40/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5181 - accuracy: 0.7429 - val_loss: 0.7301 - val_accuracy: 0.5750
# Epoch 41/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.7723 - val_loss: 0.7056 - val_accuracy: 0.5571
# Epoch 42/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4857 - accuracy: 0.7643 - val_loss: 0.7556 - val_accuracy: 0.5571
# Epoch 43/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5071 - accuracy: 0.7437 - val_loss: 0.7315 - val_accuracy: 0.5571
# Epoch 44/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.4786 - accuracy: 0.7848 - val_loss: 0.7156 - val_accuracy: 0.5750
# Epoch 45/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4776 - accuracy: 0.7732 - val_loss: 0.7074 - val_accuracy: 0.5857
# Epoch 46/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4821 - accuracy: 0.7661 - val_loss: 0.6919 - val_accuracy: 0.5821
# Epoch 47/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4924 - accuracy: 0.7589 - val_loss: 0.8263 - val_accuracy: 0.5714
# Epoch 48/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4939 - accuracy: 0.7652 - val_loss: 0.7246 - val_accuracy: 0.5893
# Epoch 49/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4700 - accuracy: 0.7920 - val_loss: 0.7322 - val_accuracy: 0.5893
# Epoch 50/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.7964 - val_loss: 1.0084 - val_accuracy: 0.5429
# Epoch 51/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.7732 - val_loss: 0.8635 - val_accuracy: 0.5643
# Epoch 52/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4587 - accuracy: 0.7795 - val_loss: 0.7863 - val_accuracy: 0.6107
# Epoch 53/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.7964 - val_loss: 1.1952 - val_accuracy: 0.5393
# Epoch 54/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.7946 - val_loss: 0.7478 - val_accuracy: 0.5893
# Epoch 55/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4458 - accuracy: 0.7893 - val_loss: 0.7153 - val_accuracy: 0.6071
# Epoch 56/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4514 - accuracy: 0.7821 - val_loss: 0.7315 - val_accuracy: 0.5857
# Epoch 57/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.7946 - val_loss: 0.7247 - val_accuracy: 0.5857
# Epoch 58/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.7857 - val_loss: 0.7929 - val_accuracy: 0.5929
# Epoch 59/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.7964 - val_loss: 1.0959 - val_accuracy: 0.4786
# Epoch 60/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4261 - accuracy: 0.7991 - val_loss: 0.7399 - val_accuracy: 0.5929
# Epoch 61/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4534 - accuracy: 0.7884 - val_loss: 0.7888 - val_accuracy: 0.5571
# Epoch 62/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4333 - accuracy: 0.7964 - val_loss: 0.7562 - val_accuracy: 0.5929
# Epoch 63/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4228 - accuracy: 0.7991 - val_loss: 0.8949 - val_accuracy: 0.5214
# Epoch 64/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4529 - accuracy: 0.7946 - val_loss: 0.7547 - val_accuracy: 0.5929
# Epoch 65/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3830 - accuracy: 0.8321 - val_loss: 0.7867 - val_accuracy: 0.5714
# Epoch 66/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4294 - accuracy: 0.8045 - val_loss: 0.7930 - val_accuracy: 0.5821
# Epoch 67/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4219 - accuracy: 0.8161 - val_loss: 0.7640 - val_accuracy: 0.5714
# Epoch 68/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4207 - accuracy: 0.8161 - val_loss: 0.7923 - val_accuracy: 0.5679
# Epoch 69/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4296 - accuracy: 0.8152 - val_loss: 0.9331 - val_accuracy: 0.5179
# Epoch 70/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3974 - accuracy: 0.8241 - val_loss: 0.7532 - val_accuracy: 0.5929
# Epoch 71/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8214 - val_loss: 0.9703 - val_accuracy: 0.5500
# Epoch 72/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3754 - accuracy: 0.8393 - val_loss: 0.7749 - val_accuracy: 0.5750
# Epoch 73/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8161 - val_loss: 1.3449 - val_accuracy: 0.5429
# Epoch 74/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3899 - accuracy: 0.8420 - val_loss: 0.8080 - val_accuracy: 0.5786
# Epoch 75/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8321 - val_loss: 0.9612 - val_accuracy: 0.5643
# Epoch 76/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4154 - accuracy: 0.8000 - val_loss: 0.9620 - val_accuracy: 0.5286
# Epoch 77/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8464 - val_loss: 0.7774 - val_accuracy: 0.5964
# Epoch 78/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8250 - val_loss: 0.8233 - val_accuracy: 0.5571
# Epoch 79/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8473 - val_loss: 0.9049 - val_accuracy: 0.5893
# Epoch 80/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8384 - val_loss: 0.8560 - val_accuracy: 0.6036
# Epoch 81/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8429 - val_loss: 0.8991 - val_accuracy: 0.5964
# Epoch 82/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.8661 - val_loss: 0.9277 - val_accuracy: 0.5821
# Epoch 83/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8304 - val_loss: 1.1430 - val_accuracy: 0.5500
# Epoch 84/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3225 - accuracy: 0.8598 - val_loss: 0.9367 - val_accuracy: 0.5786
# Epoch 85/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3348 - accuracy: 0.8554 - val_loss: 0.8703 - val_accuracy: 0.6107
# Epoch 86/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3111 - accuracy: 0.8804 - val_loss: 0.9542 - val_accuracy: 0.5321
# Epoch 87/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3731 - accuracy: 0.8393 - val_loss: 0.8192 - val_accuracy: 0.5536
# Epoch 88/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4126 - accuracy: 0.8464 - val_loss: 0.8725 - val_accuracy: 0.5464
# Epoch 89/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8643 - val_loss: 0.7953 - val_accuracy: 0.5857
# Epoch 90/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8455 - val_loss: 0.9302 - val_accuracy: 0.6036
# Epoch 91/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3688 - accuracy: 0.8259 - val_loss: 0.8963 - val_accuracy: 0.5893
# Epoch 92/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.3564 - accuracy: 0.8509 - val_loss: 0.8641 - val_accuracy: 0.5929
# Epoch 93/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2929 - accuracy: 0.8830 - val_loss: 1.3785 - val_accuracy: 0.5464
# Epoch 94/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.8589 - val_loss: 0.8310 - val_accuracy: 0.5857
# Epoch 95/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3588 - accuracy: 0.8589 - val_loss: 0.9304 - val_accuracy: 0.6036
# Epoch 96/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3114 - accuracy: 0.8777 - val_loss: 1.0341 - val_accuracy: 0.5571
# Epoch 97/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8955 - val_loss: 0.8395 - val_accuracy: 0.6000
# Epoch 98/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2943 - accuracy: 0.8821 - val_loss: 1.3202 - val_accuracy: 0.5571
# Epoch 99/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2982 - accuracy: 0.8714 - val_loss: 0.8255 - val_accuracy: 0.6107
# Epoch 100/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3072 - accuracy: 0.8830 - val_loss: 0.8551 - val_accuracy: 0.5750
# Epoch 101/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3158 - accuracy: 0.8705 - val_loss: 0.8751 - val_accuracy: 0.5929
# Epoch 102/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3179 - accuracy: 0.8714 - val_loss: 1.0047 - val_accuracy: 0.5893
# Epoch 103/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8679 - val_loss: 0.8257 - val_accuracy: 0.5893
# Epoch 104/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2849 - accuracy: 0.8938 - val_loss: 0.9049 - val_accuracy: 0.5821
# Epoch 105/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2767 - accuracy: 0.8830 - val_loss: 0.8688 - val_accuracy: 0.5750
# Epoch 106/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3228 - accuracy: 0.8607 - val_loss: 0.9917 - val_accuracy: 0.5821
# Epoch 107/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.9179 - val_loss: 0.9017 - val_accuracy: 0.5607
# Epoch 108/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3156 - accuracy: 0.8687 - val_loss: 0.9235 - val_accuracy: 0.5857
# Epoch 109/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3560 - accuracy: 0.8616 - val_loss: 0.8390 - val_accuracy: 0.5786
# Epoch 110/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.9080 - val_loss: 0.9387 - val_accuracy: 0.5750
# Epoch 111/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2569 - accuracy: 0.9036 - val_loss: 0.8845 - val_accuracy: 0.5857
# Epoch 112/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.9036 - val_loss: 0.8776 - val_accuracy: 0.5929
# Epoch 113/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3138 - accuracy: 0.8821 - val_loss: 0.8692 - val_accuracy: 0.5964
# Epoch 114/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2097 - accuracy: 0.9286 - val_loss: 0.9631 - val_accuracy: 0.5464
# Epoch 115/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3315 - accuracy: 0.8545 - val_loss: 0.8645 - val_accuracy: 0.6000
# Epoch 116/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2075 - accuracy: 0.9366 - val_loss: 1.1313 - val_accuracy: 0.5607
# Epoch 117/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2428 - accuracy: 0.9018 - val_loss: 1.0221 - val_accuracy: 0.5679
# Epoch 118/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.9027 - val_loss: 1.2942 - val_accuracy: 0.5536
# Epoch 119/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2383 - accuracy: 0.9286 - val_loss: 0.9041 - val_accuracy: 0.5607
# Epoch 120/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9170 - val_loss: 1.1163 - val_accuracy: 0.5607
# Epoch 121/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2172 - accuracy: 0.9250 - val_loss: 0.9977 - val_accuracy: 0.5643
# Epoch 122/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1892 - accuracy: 0.9348 - val_loss: 1.0206 - val_accuracy: 0.5714
# Epoch 123/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2944 - accuracy: 0.8920 - val_loss: 1.0480 - val_accuracy: 0.5750
# Epoch 124/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.9036 - val_loss: 1.0711 - val_accuracy: 0.5571
# Epoch 125/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2074 - accuracy: 0.9241 - val_loss: 0.9824 - val_accuracy: 0.5536
# Epoch 126/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9214 - val_loss: 0.9721 - val_accuracy: 0.5857
# Epoch 127/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2343 - accuracy: 0.9107 - val_loss: 0.9638 - val_accuracy: 0.5857
# Epoch 128/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8759 - val_loss: 1.3892 - val_accuracy: 0.5571
# Epoch 129/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2063 - accuracy: 0.9286 - val_loss: 1.1649 - val_accuracy: 0.5536
# Epoch 130/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2350 - accuracy: 0.9214 - val_loss: 1.0094 - val_accuracy: 0.5857
# Epoch 131/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1576 - accuracy: 0.9598 - val_loss: 1.1727 - val_accuracy: 0.5571
# Epoch 132/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2161 - accuracy: 0.9286 - val_loss: 1.2728 - val_accuracy: 0.5571
# Epoch 133/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.9134 - val_loss: 1.0020 - val_accuracy: 0.5893
# Epoch 134/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.9125 - val_loss: 1.1183 - val_accuracy: 0.5571
# Epoch 135/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2419 - accuracy: 0.9152 - val_loss: 1.1931 - val_accuracy: 0.5536
# Epoch 136/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2117 - accuracy: 0.9241 - val_loss: 1.0384 - val_accuracy: 0.5821
# Epoch 137/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1695 - accuracy: 0.9411 - val_loss: 1.1296 - val_accuracy: 0.5286
# Epoch 138/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1508 - accuracy: 0.9554 - val_loss: 1.0157 - val_accuracy: 0.5821
# Epoch 139/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1647 - accuracy: 0.9446 - val_loss: 1.0044 - val_accuracy: 0.5821
# Epoch 140/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1731 - accuracy: 0.9420 - val_loss: 1.0226 - val_accuracy: 0.5714
# Epoch 141/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1716 - accuracy: 0.9375 - val_loss: 1.0041 - val_accuracy: 0.5714
# Epoch 142/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1358 - accuracy: 0.9688 - val_loss: 1.1235 - val_accuracy: 0.5643
# Epoch 143/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8857 - val_loss: 1.0166 - val_accuracy: 0.5214
# Epoch 144/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9652 - val_loss: 1.0580 - val_accuracy: 0.5750
# Epoch 145/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9205 - val_loss: 1.0002 - val_accuracy: 0.5750
# Epoch 146/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2186 - accuracy: 0.9286 - val_loss: 1.1545 - val_accuracy: 0.5714
# Epoch 147/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2322 - accuracy: 0.9116 - val_loss: 1.0433 - val_accuracy: 0.5500
# Epoch 148/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9455 - val_loss: 1.1115 - val_accuracy: 0.5714
# Epoch 149/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1700 - accuracy: 0.9446 - val_loss: 1.1019 - val_accuracy: 0.5607
# Epoch 150/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.9705 - val_loss: 1.1243 - val_accuracy: 0.5643
# Epoch 151/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1794 - accuracy: 0.9500 - val_loss: 1.0840 - val_accuracy: 0.5679
# Epoch 152/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2907 - accuracy: 0.8964 - val_loss: 1.2484 - val_accuracy: 0.5679
# Epoch 153/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3101 - accuracy: 0.9000 - val_loss: 1.1303 - val_accuracy: 0.5607
# Epoch 154/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9670 - val_loss: 1.2186 - val_accuracy: 0.5536
# Epoch 155/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9634 - val_loss: 1.1718 - val_accuracy: 0.5643
# Epoch 156/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9268 - val_loss: 1.1644 - val_accuracy: 0.5679
# Epoch 157/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.9741 - val_loss: 1.2339 - val_accuracy: 0.5571
# Epoch 158/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9438 - val_loss: 0.9930 - val_accuracy: 0.5714
# Epoch 159/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9696 - val_loss: 1.1125 - val_accuracy: 0.5893
# Epoch 160/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9393 - val_loss: 1.0983 - val_accuracy: 0.5750
# Epoch 161/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2770 - accuracy: 0.8938 - val_loss: 1.0850 - val_accuracy: 0.5679
# Epoch 162/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9652 - val_loss: 1.8613 - val_accuracy: 0.5036
# Epoch 163/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1641 - accuracy: 0.9429 - val_loss: 1.0377 - val_accuracy: 0.5786
# Epoch 164/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.9830 - val_loss: 1.7553 - val_accuracy: 0.5536
# Epoch 165/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1769 - accuracy: 0.9536 - val_loss: 1.1061 - val_accuracy: 0.5786
# Epoch 166/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9580 - val_loss: 1.1749 - val_accuracy: 0.5750
# Epoch 167/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0940 - accuracy: 0.9812 - val_loss: 1.1277 - val_accuracy: 0.5607
# Epoch 168/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9500 - val_loss: 1.0856 - val_accuracy: 0.5750
# Epoch 169/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9518 - val_loss: 1.1383 - val_accuracy: 0.5643
# Epoch 170/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1034 - accuracy: 0.9723 - val_loss: 1.3011 - val_accuracy: 0.5357
# Epoch 171/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0930 - accuracy: 0.9795 - val_loss: 1.2413 - val_accuracy: 0.5607
# Epoch 172/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1934 - accuracy: 0.9357 - val_loss: 0.9949 - val_accuracy: 0.5786
# Epoch 173/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9491 - val_loss: 1.2363 - val_accuracy: 0.5571
# Epoch 174/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1188 - accuracy: 0.9625 - val_loss: 1.1983 - val_accuracy: 0.5643
# Epoch 175/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9812 - val_loss: 1.1443 - val_accuracy: 0.5786
# Epoch 176/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 0.9848 - val_loss: 1.2274 - val_accuracy: 0.5536
# Epoch 177/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0971 - accuracy: 0.9777 - val_loss: 1.1845 - val_accuracy: 0.5679
# Epoch 178/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3065 - accuracy: 0.9000 - val_loss: 1.1935 - val_accuracy: 0.5607
# Epoch 179/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9554 - val_loss: 1.1807 - val_accuracy: 0.5679
# Epoch 180/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9563 - val_loss: 1.0907 - val_accuracy: 0.5643
# Epoch 181/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0791 - accuracy: 0.9893 - val_loss: 1.3915 - val_accuracy: 0.5357
# Epoch 182/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2413 - accuracy: 0.9232 - val_loss: 1.1976 - val_accuracy: 0.5893
# Epoch 183/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1413 - accuracy: 0.9545 - val_loss: 1.1769 - val_accuracy: 0.5821
# Epoch 184/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9768 - val_loss: 1.5251 - val_accuracy: 0.5571
# Epoch 185/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 0.9866 - val_loss: 1.1736 - val_accuracy: 0.5714
# Epoch 186/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.9866 - val_loss: 1.7557 - val_accuracy: 0.5607
# Epoch 187/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.9795 - val_loss: 1.2266 - val_accuracy: 0.5786
# Epoch 188/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1275 - accuracy: 0.9661 - val_loss: 1.1964 - val_accuracy: 0.5679
# Epoch 189/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2317 - accuracy: 0.9241 - val_loss: 1.2453 - val_accuracy: 0.5714
# Epoch 190/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.9875 - val_loss: 1.3458 - val_accuracy: 0.5429
# Epoch 191/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0659 - accuracy: 0.9893 - val_loss: 1.3268 - val_accuracy: 0.5643
# Epoch 192/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 0.9911 - val_loss: 1.4575 - val_accuracy: 0.5500
# Epoch 193/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0737 - accuracy: 0.9830 - val_loss: 1.2814 - val_accuracy: 0.5571
# Epoch 194/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0604 - accuracy: 0.9911 - val_loss: 1.2357 - val_accuracy: 0.5929
# Epoch 195/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9937 - val_loss: 1.2450 - val_accuracy: 0.5821
# Epoch 196/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0570 - accuracy: 0.9884 - val_loss: 1.2098 - val_accuracy: 0.5714
# Epoch 197/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9545 - val_loss: 1.2916 - val_accuracy: 0.5786
# Epoch 198/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 0.9929 - val_loss: 1.2779 - val_accuracy: 0.5786
# Epoch 199/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0530 - accuracy: 0.9937 - val_loss: 1.2689 - val_accuracy: 0.5679
# Epoch 200/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1339 - accuracy: 0.9518 - val_loss: 1.2425 - val_accuracy: 0.5750

# %% [markdown]
# #### Display the history after running `model.fit`

# %%
# Retrieve training results

train_loss = history.history["loss"]
train_acc  = history.history["accuracy"]
valid_loss = history.history["val_loss"]
valid_acc  = history.history["val_accuracy"]

# %%
plt.figure(figsize=(12,6))

# Adjust the value of 'step' to plot the results every 'step' epoch.
# This allows you to have cleaner plot when the number of epochs are large

step = 1
x_range = range(0, len(train_loss), step)
plt.plot(x_range, train_loss[ : :step], color='DodgerBlue', label='Train Data')
plt.plot(x_range, valid_loss[ : :step], color='orange', label='Validation Data')

plt.title('Loss Function vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,5))

# Adjust the value of 'step' to plot the results every 'step' epoch.
# This allows you to have cleaner plot when the number of epochs are large

step = 1
x_range = range(0, len(train_acc), step)
plt.plot(x_range, train_acc[ : :step], color='DodgerBlue', label='Train Data')
plt.plot(x_range, valid_acc[ : :step], color='orange', label='Validation Data')

plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### <font color=blue>4. Test and Evaluate the Model on Train Data</font>

# %%
loss, accuracy = model.evaluate(X_train, y_train)
# Out:
# 44/44 [==============================] - 0s 828us/step - loss: 0.2908 - accuracy: 0.9100

# %% [markdown]
# ### <font color=blue>5. Predicted target output, Y</font>

# %%
Y_pred = model.predict(X_train)
# Out:
# 44/44 [==============================] - 0s 720us/step

# %% [markdown]
# ### Examine the histogram of the output layer output, $\hat{Y}$

# %%
plt.hist(Y_pred)
# Out:
# (array([620.,  67.,  34.,  19.,  18.,  14.,  23.,  35.,  74., 496.]),
#  array([5.6131421e-07, 1.0000042e-01, 2.0000027e-01, 3.0000013e-01,
#         3.9999998e-01, 4.9999982e-01, 5.9999967e-01, 6.9999957e-01,
#         7.9999942e-01, 8.9999926e-01, 9.9999911e-01], dtype=float32),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### <font color=maroon> This indicates the training accuracy is very high since the probability values are mostly 0 or 1.</font>

# %% [markdown]
# ### We need to validate the performance against the test dataset

# %% [markdown]
# ### <font color=blue>6. Evaluation on the Test Data </font>

# %%
loss_t, accuracy_t = model.evaluate(X_test, y_test)
# Out:
# 19/19 [==============================] - 0s 1ms/step - loss: 1.2461 - accuracy: 0.5733

# %%
Y_pred_t = model.predict(X_test)
plt.hist(Y_pred_t)
plt.show()
# Out:
# 19/19 [==============================] - 0s 850us/step

# %% [markdown]
# ### <font color=maroon> The evaluation on the test set is poor, only ~60%! This implies the model is overfitting the training set and may be too simple</font>

# %% [markdown]
# ## <font color=green>Build a $L$-Layer NN, $L > 2$</font>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=11)

# %%
X_train.shape, y_test.shape
# Out:
# ((1400, 12288), (600,))

# %%
L = 4

n0 = X.shape[1]

# Three hidden layers with # of neurons 20, 7 and 5.

n = np.array([n0, 20, 7, 5, 1])

# %%
n
# Out:
# array([12288,    20,     7,     5,     1])

# %%
model = Sequential()

model.add(Dense(n1, input_dim=n0, activation="relu"))

for i in range(2, L):
    model.add(Dense(n[i], activation="relu"))
    
model.add(Dense(n[L], activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 8)                 98312
#
#  dense_17 (Dense)            (None, 7)                 63
#
#  dense_18 (Dense)            (None, 5)                 40
#
#  dense_19 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 98,421
# Trainable params: 98,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = keras.optimizers.SGD(learning_rate=0.005)
model.compile(loss="binary_crossentropy", optimizer=sgd, metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=1000, batch_size=20, validation_split = 0.2, verbose=0)

# %%
loss, accuracy = model.evaluate(X_train, y_train)

Y_pred = model.predict(X_train)
# Out:
# 44/44 [==============================] - 0s 864us/step - loss: 0.8338 - accuracy: 0.9143
# 44/44 [==============================] - 0s 727us/step

# %%
# Retrieve training results

train_loss = history.history["loss"]
train_acc  = history.history["accuracy"]
valid_loss = history.history["val_loss"]
valid_acc  = history.history["val_accuracy"]

# %%
plt.figure(figsize=(12,6))

# Adjust the value of 'step' to plot the results every 'step' epoch.
# This allows you to have cleaner plot when the number of epochs are large

step = 1
x_range = range(0, len(train_loss), step)
plt.plot(x_range, train_loss[ : :step], color='DodgerBlue', label='Train Data')
plt.plot(x_range, valid_loss[ : :step], color='orange', label='Validation Data')

plt.title('Loss Function vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,5))

# Adjust the value of 'step' to plot the results every 'step' epoch.
# This allows you to have cleaner plot when the number of epochs are large

step = 25
x_range = range(0, len(train_acc), step)
plt.plot(x_range, train_acc[ : :step], color='DodgerBlue', label='Train Data')
plt.plot(x_range, valid_acc[ : :step], color='orange', label='Validation Data')

plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Evaluation on the Test Data

# %%
loss_t, accuracy_t = model.evaluate(X_test, y_test)
# Out:
# 19/19 [==============================] - 0s 977us/step - loss: 3.1957 - accuracy: 0.5850

# %% [markdown]
# ### <font color=red> Conlusion: with a deeper Neural Network, the model has overfitted the training data. Both the performance on the Validation Data and the Test Data is less than 60%! We need other NN architecture to address th
